# %%
# !pip install --upgrade pip
# !pip install mne
# Out:
# Requirement already satisfied: pip in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (25.3)
# Requirement already satisfied: mne in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (1.11.0)
# Requirement already satisfied: decorator in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.8 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (3.10.8)
# Requirement already satisfied: numpy<3,>=1.26 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (2.3.5)
# Requirement already satisfied: packaging in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (25.0)
# Requirement already satisfied: pooch>=1.5 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.11 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from matplotlib>=3.8->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from matplotlib>=3.8->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from matplotlib>=3.8->mne) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from matplotlib>=3.8->mne) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from matplotlib>=3.8->mne) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from matplotlib>=3.8->mne) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from matplotlib>=3.8->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from pooch>=1.5->mne) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from pooch>=1.5->mne) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: colorama in c:\users\sja_010525-01\anaconda3\envs\mne\lib\site-packages (from tqdm->mne) (0.4.6)

# %%
# Verify the installation
import mne
print(mne.__version__)
# Out:
# 1.11.0

# %%
import mne

# %%
data_path = mne.datasets.sample.data_path()
print(data_path)
# Out:
# Using default location ~/mne_data for sample...
# Downloading file 'MNE-sample-data-processed.tar.gz' from 'https://osf.io/download/86qa2?version=6' to 'C:\Users\SJA_010525-01\mne_data'.
# 100%|#####################################| 1.65G/1.65G [00:00<00:00, 1.50TB/s]
# Untarring contents of 'C:\Users\SJA_010525-01\mne_data\MNE-sample-data-processed.tar.gz' to 'C:\Users\SJA_010525-01\mne_data'
# Attempting to create new mne-python configuration file:
# C:\Users\SJA_010525-01\.mne\mne-python.json
# Could not read the C:\Users\SJA_010525-01\.mne\mne-python.json json file during the writing. Assuming it is empty. Got: Expecting value: line 1 column 1 (char 0)
# Download complete in 04m44s (1576.2 MB)
# C:\Users\SJA_010525-01\mne_data\MNE-sample-data
